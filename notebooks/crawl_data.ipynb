# %%
import pandas as pd
from recommender.crawl_imdb import IMDbDataPydantic, wrapper
import concurrent.futures
import tqdm
import time
import multiprocessing
import threading
from recommender import REPO_PATH
import os
os.chdir(REPO_PATH)

# %%
links = pd.read_csv(
    "data/imdb_data.csv",
    dtype={
        "movieId": "int64",
        "imdbId": "string",
        "tmdbId": "string",
    },
)
links
# Out:
#        imdbId  movieId  tmdbId  rating         director  \
# 0     0114709        1     862     8.3    John Lasseter
# 1     0113497        2    8844     7.1     Joe Johnston
# 2     0113228        3   15602     6.6    Howard Deutch
# 3     0114885        4   31357     6.0  Forest Whitaker
# 4     0113041        5   11862     6.1    Charles Shyer
# ...       ...      ...     ...     ...              ...
# 9737  5476944   193581  432131     7.6     Noriyuki Abe
# 9738  5914996   193583  445030     7.3  Atsuko Ishizuka
# 9739  6397426   193585  479308     6.2  Bruce Beresford
# 9740  8391976   193587  483455     7.3  Takuya Igarashi
# 9741  0101726   193609   37891     5.2        Jay Dubin
#
#                                            plot_summary  \
# 0     A cowboy doll is profoundly threatened and jea...
# 1     When two kids find and play a magical board ga...
# 2     John and Max resolve to save their beloved bai...
# 3     Based on Terry McMillan's novel, this film fol...
# 4     George Banks must deal not only with his daugh...
# ...                                                 ...
# 9737  A young lord and his demon butler board a luxu...
# 9738  Adaption of the sixth Light Novel of series, i...
# 9739  A woman deals with the toxic water scandal in ...
# 9740  The Armed Detective Agency investigates a biza...
# 9741  Outrageous, misogynistic and vulgar-to-the-max...
#
#                                                top_cast
# 0     Tom Hanks | Tim Allen | Don Rickles | Jim Varn...
# 1     Robin Williams | Kirsten Dunst | Bonnie Hunt |...
# 2     Walter Matthau | Jack Lemmon | Ann-Margret | S...
# 3     Whitney Houston | Angela Bassett | Loretta Dev...
# 4     Steve Martin | Diane Keaton | Martin Short | K...
# ...                                                 ...
# 9737  Bryn Apprill | Dawn M. Bennett | Justin Briner...
# 9738  Alexandra Bedford | Jessica Boone | Ricardo Co...
# 9739  Marin Ireland | Queen Latifah | Lyndie Greenwo...
# 9740  Brian Beacock | Ray Chase | Lucien Dodge | Car...
# 9741  Andrew Dice Clay | Eddie Griffin | Sylvia Harm...
#
# [9742 rows x 7 columns]

# %%
wanted_ids = links.loc[links.director.isna()].imdbId
wanted_ids
# Out:
# 585     0118114
# 4931    0070644
# 4981    0259153
# 4986    0112130
# 5011    0080297
#          ...
# 9573    6840134
# 9634    6769208
# 9651    0118460
# 9690    5189670
# 9736    5342766
# Name: imdbId, Length: 94, dtype: string

# %%
def fetch_imdb_data_with_timeout(imdbid, timeout = 6):
    # Create a multiprocessing Queue to get the function result
    queue = multiprocessing.Queue()

    # Define a wrapper function to call the original function and put its result into the queue

    # Create and start a Process to run the wrapper function
    process = multiprocessing.Process(target=wrapper, args=(queue, imdbid))
    process.start()

    # Wait for the process to finish or timeout
    process.join(timeout)
    if process.is_alive():
        # If the process is still alive after the timeout, terminate it
        process.terminate()
        process.join()
        return "Timeout reached"

    try:
        # Get the result from the queue
        result = queue.get_nowait()
    except multiprocessing.queues.Empty:
        return "No result returned"

    return result

data = fetch_imdb_data_with_timeout('1234567')  # 10 seconds ti

# %%
with concurrent.futures.ThreadPoolExecutor(max_workers=4) as executor:
    future_to_imdb_id = {executor.submit(fetch_imdb_data_with_timeout, imdb_id): imdb_id for imdb_id in wanted_ids}

    results = {}
    i = 0

    for future in tqdm.tqdm(concurrent.futures.as_completed(future_to_imdb_id), total=len(future_to_imdb_id)):
        imdb_id = future_to_imdb_id[future]
        try:
            data = future.result()
            results[imdb_id] = data
        except concurrent.futures.TimeoutError:
            print(f"Fetching data for IMDb ID {imdb_id} timed out.")
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]2023-12-11 18:33:44.686 | INFO     | recommender.crawl_imdb:fetch_imdb_data:95 - Network error occurred: 404 Client Error: Not Found for url: https://www.imdb.com/title/tt0118114/ for https://www.imdb.com/title/tt0118114/
#   1%|          | 1/94 [00:01<02:43,  1.75s/it]2023-12-11 18:33:45.094 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0259153/plotsummary/
# 2023-12-11 18:33:45.103 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0070644/plotsummary/
# 2023-12-11 18:33:45.148 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0112130/plotsummary/
#   4%|▍         | 4/94 [00:03<00:56,  1.59it/s]2023-12-11 18:33:47.368 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0080297/plotsummary/
# 2023-12-11 18:33:48.001 | INFO     | recommender.crawl_imdb:fetch_imdb_data:99 - Failed to parse IMDb page - the page structure may have changed.
# director wrong
#  for https://www.imdb.com/title/tt0142032/
#   5%|▌         | 5/94 [00:05<01:27,  1.02it/s]2023-12-11 18:33:48.067 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0287839/plotsummary/
# 2023-12-11 18:33:48.134 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0081874/plotsummary/
#   7%|▋         | 7/94 [00:06<01:05,  1.34it/s]2023-12-11 18:33:49.943 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0083480/plotsummary/
# 2023-12-11 18:33:50.041 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0088727/plotsummary/
#  11%|█         | 10/94 [00:08<00:51,  1.64it/s]2023-12-11 18:33:51.273 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0092337/plotsummary/
#  12%|█▏        | 11/94 [00:09<01:03,  1.30it/s]2023-12-11 18:33:52.802 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0096639/plotsummary/
# 2023-12-11 18:33:52.959 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0099864/plotsummary/
# 2023-12-11 18:33:53.501 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0094791/plotsummary/
#  15%|█▍        | 14/94 [00:11<00:54,  1.48it/s]2023-12-11 18:33:55.212 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0103516/plotsummary/
# 2023-12-11 18:33:55.766 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0108941/plotsummary/
# 2023-12-11 18:33:55.821 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0112040/plotsummary/
#  16%|█▌        | 15/94 [00:13<01:16,  1.03it/s]2023-12-11 18:33:56.269 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0120570/plotsummary/
#  19%|█▉        | 18/94 [00:14<00:44,  1.71it/s]2023-12-11 18:33:58.556 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0207275/plotsummary/
# 2023-12-11 18:33:58.652 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0130414/plotsummary/
# 2023-12-11 18:33:58.882 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0314979/plotsummary/
# 2023-12-11 18:33:59.212 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0328832/plotsummary/
#  23%|██▎       | 22/94 [00:18<01:04,  1.12it/s]2023-12-11 18:34:01.797 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0340477/plotsummary/
# 2023-12-11 18:34:01.980 | INFO     | recommender.crawl_imdb:fetch_imdb_data:99 - Failed to parse IMDb page - the page structure may have changed.
# director wrong
#  for https://www.imdb.com/title/tt0355987/
#  24%|██▍       | 23/94 [00:19<00:53,  1.33it/s]2023-12-11 18:34:02.587 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0105946/plotsummary/
#  27%|██▋       | 25/94 [00:20<00:53,  1.29it/s]2023-12-11 18:34:03.839 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0783612/plotsummary/
# 2023-12-11 18:34:04.123 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0118414/plotsummary/
#  29%|██▊       | 27/94 [00:21<00:45,  1.46it/s]2023-12-11 18:34:05.975 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0070904/plotsummary/
# 2023-12-11 18:34:06.505 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0472027/plotsummary/
# 2023-12-11 18:34:06.662 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0430484/plotsummary/
# 2023-12-11 18:34:06.711 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0279077/plotsummary/
#  33%|███▎      | 31/94 [00:24<00:33,  1.85it/s]2023-12-11 18:34:09.426 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt
| INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0374463/plotsummary/
# 2023-12-11 18:34:34.107 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt2044056/plotsummary/
#  71%|███████▏  | 67/94 [00:52<00:14,  1.85it/s]2023-12-11 18:34:36.567 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt4299972/plotsummary/
# 2023-12-11 18:34:36.590 | INFO     | recommender.crawl_imdb:fetch_imdb_data:99 - Failed to parse IMDb page - the page structure may have changed.
# director wrong
#  for https://www.imdb.com/title/tt0465316/
#  72%|███████▏  | 68/94 [00:53<00:19,  1.33it/s]2023-12-11 18:34:37.061 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt4705522/plotsummary/
#  73%|███████▎  | 69/94 [00:54<00:19,  1.28it/s]2023-12-11 18:34:37.990 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0830361/plotsummary/
#  74%|███████▍  | 70/94 [00:55<00:17,  1.40it/s]2023-12-11 18:34:38.814 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0075468/plotsummary/
#  76%|███████▌  | 71/94 [00:56<00:18,  1.26it/s]2023-12-11 18:34:39.383 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0296310/plotsummary/
#  77%|███████▋  | 72/94 [00:56<00:16,  1.32it/s]2023-12-11 18:34:39.994 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0083100/plotsummary/
#  79%|███████▊  | 74/94 [00:57<00:13,  1.46it/s]2023-12-11 18:34:41.401 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0086333/plotsummary/
# 2023-12-11 18:34:41.596 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0091942/plotsummary/
# 2023-12-11 18:34:42.321 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0079902/plotsummary/
#  82%|████████▏ | 77/94 [01:00<00:11,  1.51it/s]2023-12-11 18:34:43.590 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt3910804/plotsummary/
#  83%|████████▎ | 78/94 [01:01<00:13,  1.16it/s]2023-12-11 18:34:44.691 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt3718778/plotsummary/
# 2023-12-11 18:34:45.046 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0795176/plotsummary/
# 2023-12-11 18:34:45.119 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt4635282/plotsummary/
#  86%|████████▌ | 81/94 [01:03<00:08,  1.55it/s]2023-12-11 18:34:46.785 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0185906/plotsummary/
#  87%|████████▋ | 82/94 [01:04<00:10,  1.16it/s]2023-12-11 18:34:48.024 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0081846/plotsummary/
# 2023-12-11 18:34:48.125 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt5491994/plotsummary/
# 2023-12-11 18:34:48.546 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0877057/plotsummary/
#  90%|█████████ | 85/94 [01:06<00:05,  1.56it/s]2023-12-11 18:34:49.951 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0422618/plotsummary/
# 2023-12-11 18:34:50.728 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt3066856/plotsummary/
#  91%|█████████▏| 86/94 [01:07<00:06,  1.21it/s]2023-12-11 18:34:50.885 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0219263/plotsummary/
# 2023-12-11 18:34:51.276 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0115195/plotsummary/
#  95%|█████████▍| 89/94 [01:09<00:02,  1.75it/s]2023-12-11 18:34:52.907 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt6840134/plotsummary/
# 2023-12-11 18:34:53.660 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt6769208/plotsummary/
# 2023-12-11 18:34:53.763 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt0118460/plotsummary/
#  96%|█████████▌| 90/94 [01:10<00:03,  1.19it/s]2023-12-11 18:34:54.177 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt5189670/plotsummary/
#  99%|█████████▉| 93/94 [01:12<00:00,  1.71it/s]2023-12-11 18:34:57.973 | INFO     | recommender.crawl_imdb:fetch_imdb_data:52 - Could not find director for https://www.imdb.com/title/tt5342766/plotsummary/
# 100%|██████████| 94/94 [01:15<00:00,  1.24it/s]

# %%
df = links.set_index("imdbId").copy()
v : IMDbDataPydantic
for i,v in results.items():
    
    if not isinstance(v, IMDbDataPydantic):
        continue
    
    df.loc[i, "rating"] = v.rating
    df.loc[i, "director"] = v.director
    df.loc[i, "plot_summary"] = v.plot_summary
    df.loc[i, "top_cast"] = " | ".join(v.top_cast)
    
df.to_csv("data/imdb_data.csv")

# %%
df.plot_summary.isna().mean()
# Out:
# 0.000821186614658181
